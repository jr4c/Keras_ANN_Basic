# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow.contrib.keras as k
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv("data/train.csv")

# %%
categorical = [c for c in data.columns if c.find("_cat") > 0]
binary = [c for c in data.columns if c.find("_bin") > 0]
numerical = [c for c in data.columns if not c in categorical+binary]

# %%
data.describe()
# Out:
#                  id         target      ps_ind_01  ps_ind_02_cat  \
# count  5.952120e+05  595212.000000  595212.000000  595212.000000
# mean   7.438036e+05       0.036448       1.900378       1.358943
# std    4.293678e+05       0.187401       1.983789       0.664594
# min    7.000000e+00       0.000000       0.000000      -1.000000
# 25%    3.719915e+05       0.000000       0.000000       1.000000
# 50%    7.435475e+05       0.000000       1.000000       1.000000
# 75%    1.115549e+06       0.000000       3.000000       2.000000
# max    1.488027e+06       1.000000       7.000000       4.000000
#
#            ps_ind_03  ps_ind_04_cat  ps_ind_05_cat  ps_ind_06_bin  \
# count  595212.000000  595212.000000  595212.000000  595212.000000
# mean        4.423318       0.416794       0.405188       0.393742
# std         2.699902       0.493311       1.350642       0.488579
# min         0.000000      -1.000000      -1.000000       0.000000
# ...

# %%
data[categorical+binary].describe()
# Out:
#        ps_ind_02_cat  ps_ind_04_cat  ps_ind_05_cat  ps_car_01_cat  \
# count  595212.000000  595212.000000  595212.000000  595212.000000
# mean        1.358943       0.416794       0.405188       8.295933
# std         0.664594       0.493311       1.350642       2.508270
# min        -1.000000      -1.000000      -1.000000      -1.000000
# 25%         1.000000       0.000000       0.000000       7.000000
# 50%         1.000000       0.000000       0.000000       7.000000
# 75%         2.000000       1.000000       0.000000      11.000000
# max         4.000000       1.000000       6.000000      11.000000
#
#        ps_car_02_cat  ps_car_03_cat  ps_car_04_cat  ps_car_05_cat  \
# count  595212.000000  595212.000000  595212.000000  595212.000000
# mean        0.829931      -0.504899       0.725192      -0.157732
# std         0.375716       0.788654       2.153463       0.844417
# min        -1.000000      -1.000000       0.000000      -1.000000
# ...

# %%
n = data[numerical].copy()

# %%
n.drop(['id'],inplace=True,axis=1)

# %%
y_train = np.array(n.loc[:,'target':'target'].copy())
x_train = np.array(n.drop(['target'],axis=1).copy())

# %%
x_train, x_test, y_train, y_test = train_test_split(x_train,y_train,test_size=0.3)

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
N_FEATURES = 26

# %%
inputs = k.layers.Input(shape=[N_FEATURES])
net = inputs

net = k.layers.Dense(64,use_bias=False,activation=None)(net)
net = k.layers.BatchNormalization()(net)
net = k.layers.Activation("relu")(net)

net = k.layers.Dense(48,use_bias=False,activation=None)(net)
net = k.layers.BatchNormalization()(net)
net = k.layers.Activation("relu")(net)

net = k.layers.Dense(36,use_bias=False,activation=None)(net)
net = k.layers.BatchNormalization()(net)
net = k.layers.Activation("relu")(net)

net = k.layers.Dropout(0.4)(net)

net = k.layers.Dense(1,activation="sigmoid")(net)

outputs = net

# %%
model = k.models.Model(inputs,outputs)

# %%
o = k.optimizers.Adam(lr=0.0001)
l = k.losses.binary_crossentropy
m = ["acc"]
model.compile(optimizer=o,loss=l,metrics=m)

# %%
model.fit(x_train,y_train,batch_size=2500,epochs=10,validation_split=0.2)
# Out:
# Train on 333318 samples, validate on 83330 samples
# Epoch 1/10
# 333318/333318 [==============================] - 3s - loss: 0.9611 - acc: 0.4120 - val_loss: 0.7416 - val_acc: 0.2904
# Epoch 2/10
# 333318/333318 [==============================] - 2s - loss: 0.7979 - acc: 0.5132 - val_loss: 0.6608 - val_acc: 0.6294
# Epoch 3/10
# 333318/333318 [==============================] - 2s - loss: 0.6669 - acc: 0.6206 - val_loss: 0.5514 - val_acc: 0.8579
# Epoch 4/10
# 333318/333318 [==============================] - 2s - loss: 0.5649 - acc: 0.7151 - val_loss: 0.4597 - val_acc: 0.9364
# Epoch 5/10
# 333318/333318 [==============================] - 2s - loss: 0.4854 - acc: 0.7900 - val_loss: 0.3885 - val_acc: 0.9577
# Epoch 6/10
# 333318/333318 [==============================] - 2s - loss: 0.4233 - acc: 0.8438 - val_loss: 0.3370 - val_acc: 0.9618
# Epoch 7/10
# 333318/333318 [==============================] - 2s - loss: 0.3744 - acc: 0.8802 - val_loss: 0.2963 - val_acc: 0.9623
# Epoch 8/10
# ...

# %%
print(model.evaluate(scaler.transform(x_test),y_test))
print(model.metrics_names)
# Out:
# [0.21634339029030952, 0.96383929571470173]
# ['loss', 'acc']

# %%
test_data = pd.read_csv("data/test.csv")
ids = test_data.loc[:,"id":"id"]
test_data = test_data[numerical[2:]]
test_data = scaler.transform(np.array(test_data))

# %%
y_hat = model.predict(test_data,batch_size=2500)

# %%
csv_pd = pd.DataFrame({'id': [i for ii in np.array(ids) for i in ii], 'target': [i for ii in np.round(y_hat,4) for i in ii]})

# %%
csv_pd.to_csv("data/result.csv",index=False)
